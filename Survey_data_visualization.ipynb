# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/Survey-analysis/blob/main/Survey_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Seaborn 한글깨짐 해결위한 install

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# # 엑셀 데이터프레임으로 불러오기

# %%
import pandas as pd
df=pd.read_excel('/content/survey.xlsx')
df
# Out:
#     [1-1] 성별을 선택해주세요.  [1-2] 연령대를 선택해주세요.  [2-1] 주당(1주) 구내식당 이용빈도를 선택해주세요.  \
# 0                   1                   3                                2
# 1                   2                   3                                1
# 2                   1                   3                                3
# 3                   1                   3                                3
# 4                   1                   3                                3
# 5                   1                   3                                1
# 6                   1                   3                                3
# 7                   2                   3                                3
# 8                   2                   3                                3
# 9                   1                   3                                3
# 10                  1                   3                                3
# 11                  1                   3                                3
# 12                  1                   3                                3
# 13                  2                   3                                3
# 14                  1                   3                                3
# 15                  1                   3                                3
# 16                  1                   3                                3
# 17                  1                   3                                3
# 18                  1                   3                                3
# 19                  1                   2                                3
# 20                  1                   2                                2
# 21                  1                   2                                2
# 22                  1                   3                                2
# 23                  1                   2                                2
# 24                  1                   2                                3
# 25                  1                   2                                3
# 26                  1                   2                                1
# 27                  1                   2                                3
# 28                  1                   2                                1
# 29                  1                   2                                2
# 30                  2                   2                                2
# 31                  1                   2                                2
# 32                  1                   2                                1
# 33                  1                   2                                3
# 34                  1                   2                                3
# 35                  1                   1                                2
# 36                  1                   2                                2
# 37                  1                   1                                2
# 38                  1                   2                                3
# 39                  1                   2                                1
# 40                  1                   1                                3
# 41                  1                   1                                2
# 42                  1                   2                                3
# 43                  1                   1                                1
# 44                  1                   1                                1
# 45                  1                   2                                2
# 46                  1                   1                                1
# 47                  2                   1                                1
# 48                  1                   1                                2
# 49                  2                   1                                2
# 50                  1                   4                                3
# 51                  1                   4                                3
# 52                  1                   4                                3
# 53                  1                   4                                2
# 54                  1                   4                                3
# 55                  1                   4                                3
# 56                  1                   4                                3
# 57                  1                   4                                3
#
#     [2-2] 구내식당 선호 메뉴그룹을 선택해주세요. [3-1] 선호하는 외부식당명을 1,2,3순위를 순서대로 입력해주세요  \
# 0                             1                     1:청년다방,2:칭메이,3:택이네
# 1                             5                    1:명태골,2:고봉민김밥,3:포베이
# 2                             1          1:개성샤브샤브,2:택이네..칼국수,3:정직한한우곰탕
# 3                             1                1:개성샤브샤브,2:전주콩나물국밥,3:없음
# 4                             1              1:진사골순대국,2:인덕원비빔국수,3:조이마루
# 5                             4            1:청담한식뷔페,2:진사골 순대국,3:곤지암 국밥
# 6                             1          1:청계타워 구내식당,2:진지방순대국,3:놀부부대찌개
# 7                             5                   1:포베이,2:최고당돈까스,3:동남집
# 8                             1              1:나주곰탕,2:진사골 순대국,3:최고당돈가스
# 9                             1                      1:진지방,2:택이네,3:최고당
# 10                            5                1:엔차이나,2:진지방순대국,3:정감회식탁
# 11                            1              1:오투닭갈비,2:능이,3:순대국집(이마트옆)
# 12                            2                    1:마찌돈,2:오투닭갈비,3:칭메이
# 13                            5               1:개성샤브샤브,2:포베이 쌀국수,3:칭메이
# 14                            1                 1:최고당 돈까스,2:함흥냉면,3:뽕차이
# 15                            1            1:동남집,2:순대국집(에이스타워),3:오투닭갈비
# 16                            5                  1:개성샤브샤브,2:진지방,3:함흥면옥
# 17                            1                   1:뽕차이,2:월남선생,3:오투닭갈비
# 18                            1                  1:유미카츠,2:진사골순대국,3:월수금
# 19                            1                 1:청년다방,2:나주곰탕,3:개성샤브샤브
# 20                            1         1:월수금 돼지김치,2:놀부 부대찌개,3:응급실 떡볶이
# 21                            5                    1:뽕차이,2:마찌돈,3:신촌감자탕
# 22                            2              1:청담 한식뷔페,2:뽕차이,3:놀부 부대찌개
# 23                            5                      1:함흥냉면,2:마찌돈,3:돈뚝
# 24                            2             1:진지방 순대국,2:택이네 조개전골,3:뽕차이
# 25                            5                  1:마찌돈,2:놀부부대찌게,3:한우곰탕
# 26                            5                   1:서브웨이,2:맘스터치,3:롯데리아
# 27                            1           1:청계에이스타워 한식뷔페,2:진사골,3:오투닭갈비
# 28                            4       1:참진(육개장 칼국수),2:마찌돈,3:신촌 뼈다귀 해장국
# 29                            1                     1:조이마루,2:신촌,3:롯데리아
# 30                            1                 1:진사골순대국밥,2:포베이,3:조이마루
# 31                            2                 1:에청타 한식뷔페,2:화로본,3:마찌돈
# 32                            1      1:1. 한식뷔페,2:2. 진사골순대국,3:3. 놀부부대찌개
# 33                            1               1:청계에이스타워,2:화로본갈비,3:조이마루
# 34                            1            1:놀부부대찌개,2:진사골순대국,3:월수금김치찌개
# 35                            1                      1:청담,2:마찌돈,3:청계국밥
# 36                            1                1:진사골순대국밥,2:월남선생,3:조이마루
# 37                            1                  1:진사골 순대국,2:뽕차이,3:마찌돈
# 38                            1                  1:동남집,2:뽕차이,3:청진동 해장국
# 39                            1          1:한우곰탕(계란말이맛집),2:명태골,3:청계한식뷔폐
# 40                            1                 1:함흥면옥,2:최고당돈가스,3:한식뷔페
# 41                            1                1:서브웨이,2:샐러드박스,3:청담한식뷔페
# 42                            1                  1:월남선생,2:조이마루,3:개성칼국수
# 43                            1                1:청담한식뷔페,2:서브웨이,3:바우네곰당
# 44                            1                 1:프랭크버거,2:롯데리아,3:스캔들버거
# 45                            1        1:1. 청계한식뷔페,2:2. 서브웨이,3:3. 나주곰탕
# 46                            5                   1:청계한식뷔페,2:참진,3:조이마루
# 47                            1                         1:돈뚝,2:오투,3:참진
# 48                            5                    1:샐러드,2:이국식탁,3:감성집밥
# 49                            3                    1:조이마루,2:쭈꾸미,3:개성샤브
# 50                            1            1:진지방순대국,2:신청진동감자탕,3:놀부부대찌개
# 51                            5                         1:모름,2:모름,3:모름
# 52                            2                            1:.,2:.,3:.
# 53                            1                      1:칭메이,2:동남집,3:탁이네
# 54                            1               1:동편옥,2:정감회식탁,3:전주명가콩나물국
# 55                            1              1:월수금,2:은희네해장국,3:전주콩나물해장국
# 56                            2                         1:없음,2:없음,3:없음
# 57                            5                            1:.,2:.,3:.
#
#                  [3-2] 해당식당을 선호하는 이유에 대해서 다양하게 적어주세요.
# 0                                            1:가깝다...
# 1   1:좋아하는 메뉴이기도 하고 주문 후 늦지 않게 음식이 나오며 나름의 합리적인 가격...
# 2                                        1:국물이 끝내줍니다.
# 3                                               1:맛있음
# 4                                             1:해장, 맛
# 5                                      1:회사 식당이 맛이 없다
# 6                                   1:다양한 메뉴 및 저렴한 가격
# 7   1:회사에 오면 그냥 일반 집밥보다는 뭔가 맛잇는거를 먹고 싶어서. 회사 구내식당은...
# 8   1:청계 에이스 타워 내에 있는 음식점들을 선호합니다... 가까워서요 ,,,,점심시...
# 9            1:개인적으로 매운 음식을 잘 먹지 못해서 순한 음식이 나오는 곳을 선호
# 10                                             1:맛있어서
# 11                1:1. 맛이 좋아서 2. 계란 반찬을 많이 줘서 3. 가까워서
# 12                                  1:맛있다 좋아하는메뉴 깔끔하다
# 13                                                NaN
# 14  1:가격이 비싸지만 값어치를 함. 맛있게 깨끗하고, 돈을 내고 대접을 받는기분이지만...
# 15                   1:외부 식당을 잘 이용안해서 사실 아는데가 많지 않아요.
# 16                                 1:개인적인 좋아하는 메뉴입니다.
# 17                   1:음식이 빨리 나오고 미리 오더가 가능하며 맛이 좋아요.
# 18                                      1:가까워서 선호합니다.
# 19                                         1:푸짐하고 맛있음
# 20                                                NaN
# 21                                            1:맛있어서요
# 22  1:청담 한식뷔페 : 다양한 메뉴를 자율배식으로 먹을 수 있다. 뽕차이 : 농협IT...
# 23                    1:가깝고 맛있어서, 점심시간에 함께하는 지인이 선호해서
# 24                                    1:가성비가 좋고 맛이 좋음
# 25                                             1:맛있어서
# 26                                              1:편해서
# 27                               1:2층 식당만 아니면 다좋습니다..
# 28                                    1:든든한 메뉴가 좋습니다~
# 29                                          1:가격대비 효율
# 30  1:좋아하는 음식을 판다. 음식이 맛있다. 도보권 내에 있다. 장부가 있다. 해장할...
# 31                                   1:가깝고 가성비가 좋습니다!
# 32  1:1. 매일매일 바뀌는 메뉴를 푸짐하게 먹을수있고 구내식당과 가격차이도 별로안남....
# 33                                                NaN
# 34                                       1:해장하기 좋습니다.
# 35                                    1:2층 식당의 대안으로..
# 36                                   1:점심에 간단히 먹기 좋네요
# 37  1:음식이 빨리 나오고 근처 식당중에 육계장이 가장 맛있는 집입니다. 해장하기 좋습...
# 38  1:가끔 국물 있는 걸 먹고 싶을 때가 있어 나가게 되면 주로 먹는다 2층은 뭔가 ...
# 39                    1:가격이 저렴함 맛이 훌륭함 직원분이 서비스의식이 있음
# 40              1:2층에서 먹기 싫을때 가까이 있는 식당이고 맛있음 메뉴가 다양함
# 41  1:점심을 가볍게 먹고싶을때는 서브웨이나 샐러드박스에 가고, 든든하게 먹고 싶을때는...
# 42                                                NaN
# 43                                          1:메뉴의 다양함
# 44                                      1:햄버거를 좋아합니다.
# 45                                  1:가성비가 좋은 것 같습니다.
# 46                                    1:다양한 메뉴와 깔끔한 맛
# 47                                           1:간이 적절함
# 48                                         1:가성비가 좋다.
# 49                                                NaN
# 50                                             1:맛있어서
# 51                                                NaN
# 52                                                1:.
# 53                        1:이용하기 편함 예약이 가능하여 식사 시간 단축
# 54            1:회식 후 해장 등 간단히 단품으로 먹을 수 있는 국물있는 음식입니다
# 55                                          1:맛있고 저렴함
# 56                                               1:없음
# 57                                                1:.

# %% [markdown]
# # 열 이름, 셀값 보기 편하게 바꾸기

# %%
## 열 이름 바꾸기
df.columns = ["성별","연령대","구내식당 이용빈도","구내식당 선호 메뉴","선호하는 외부식당","선호하는 이유"]

# %%
## 성별
df = df.replace({'성별' : 1}, "남")
df = df.replace({'성별' : 2}, "여")

# %%
## 연령대
df = df.replace({'연령대' : 1}, "20대")
df = df.replace({'연령대' : 2}, "30대")
df = df.replace({'연령대' : 3}, "40대")
df = df.replace({'연령대' : 4}, "50대")

# %%
## 이용빈도
df = df.replace({'구내식당 이용빈도' : 1}, "0~1회")
df = df.replace({'구내식당 이용빈도' : 2}, "2~3회")
df = df.replace({'구내식당 이용빈도' : 3}, "4~5회")

# %%
## 선호 메뉴
df = df.replace({'구내식당 선호 메뉴' : 1}, "감성집밥(한식)")
df = df.replace({'구내식당 선호 메뉴' : 2}, "이국식탁(양식)")
df = df.replace({'구내식당 선호 메뉴' : 3}, "양식동원(도시락)")
df = df.replace({'구내식당 선호 메뉴' : 4}, "스낵(라면, 햄버거 등)")
df = df.replace({'구내식당 선호 메뉴' : 5}, "샐러드")

# %%
df.to_excel('./Survey.xlsx')

# %%
df 
# IDEA_1
# 선호하는 외부식당은 워드클라우드가 어울려 보임
# 선호하는 이유도 워드클라우드....?
# 선호하는 외부식당 정규표현식 등으로 데이터 전처리 후 단어카운트 -> 시각화
# 
## IDEA_2
## 연령대별 이용빈도 ( 성별비중이 너무 심하긴 한데... )
## 연령대별 선호 메뉴 비중
## 연령대별 구내식당 이용빈도 비중
## 연령대 내 선호메뉴 비중
## 성별 - 선호하는 메뉴
# Out:
#    성별  연령대 구내식당 이용빈도     구내식당 선호 메뉴                          선호하는 외부식당  \
# 0   남  40대      2~3회       감성집밥(한식)                 1:청년다방,2:칭메이,3:택이네
# 1   여  40대      0~1회            샐러드                1:명태골,2:고봉민김밥,3:포베이
# 2   남  40대      4~5회       감성집밥(한식)      1:개성샤브샤브,2:택이네..칼국수,3:정직한한우곰탕
# 3   남  40대      4~5회       감성집밥(한식)            1:개성샤브샤브,2:전주콩나물국밥,3:없음
# 4   남  40대      4~5회       감성집밥(한식)          1:진사골순대국,2:인덕원비빔국수,3:조이마루
# 5   남  40대      0~1회  스낵(라면, 햄버거 등)        1:청담한식뷔페,2:진사골 순대국,3:곤지암 국밥
# 6   남  40대      4~5회       감성집밥(한식)      1:청계타워 구내식당,2:진지방순대국,3:놀부부대찌개
# 7   여  40대      4~5회            샐러드               1:포베이,2:최고당돈까스,3:동남집
# 8   여  40대      4~5회       감성집밥(한식)          1:나주곰탕,2:진사골 순대국,3:최고당돈가스
# 9   남  40대      4~5회       감성집밥(한식)                  1:진지방,2:택이네,3:최고당
# 10  남  40대      4~5회            샐러드            1:엔차이나,2:진지방순대국,3:정감회식탁
# 11  남  40대      4~5회       감성집밥(한식)          1:오투닭갈비,2:능이,3:순대국집(이마트옆)
# 12  남  40대      4~5회       이국식탁(양식)                1:마찌돈,2:오투닭갈비,3:칭메이
# 13  여  40대      4~5회            샐러드           1:개성샤브샤브,2:포베이 쌀국수,3:칭메이
# 14  남  40대      4~5회       감성집밥(한식)             1:최고당 돈까스,2:함흥냉면,3:뽕차이
# 15  남  40대      4~5회       감성집밥(한식)        1:동남집,2:순대국집(에이스타워),3:오투닭갈비
# 16  남  40대      4~5회            샐러드              1:개성샤브샤브,2:진지방,3:함흥면옥
# 17  남  40대      4~5회       감성집밥(한식)               1:뽕차이,2:월남선생,3:오투닭갈비
# 18  남  40대      4~5회       감성집밥(한식)              1:유미카츠,2:진사골순대국,3:월수금
# 19  남  30대      4~5회       감성집밥(한식)             1:청년다방,2:나주곰탕,3:개성샤브샤브
# 20  남  30대      2~3회       감성집밥(한식)     1:월수금 돼지김치,2:놀부 부대찌개,3:응급실 떡볶이
# 21  남  30대      2~3회            샐러드                1:뽕차이,2:마찌돈,3:신촌감자탕
# 22  남  40대      2~3회       이국식탁(양식)          1:청담 한식뷔페,2:뽕차이,3:놀부 부대찌개
# 23  남  30대      2~3회            샐러드                  1:함흥냉면,2:마찌돈,3:돈뚝
# 24  남  30대      4~5회       이국식탁(양식)         1:진지방 순대국,2:택이네 조개전골,3:뽕차이
# 25  남  30대      4~5회            샐러드              1:마찌돈,2:놀부부대찌게,3:한우곰탕
# 26  남  30대      0~1회            샐러드               1:서브웨이,2:맘스터치,3:롯데리아
# 27  남  30대      4~5회       감성집밥(한식)       1:청계에이스타워 한식뷔페,2:진사골,3:오투닭갈비
# 28  남  30대      0~1회  스낵(라면, 햄버거 등)   1:참진(육개장 칼국수),2:마찌돈,3:신촌 뼈다귀 해장국
# 29  남  30대      2~3회       감성집밥(한식)                 1:조이마루,2:신촌,3:롯데리아
# 30  여  30대      2~3회       감성집밥(한식)             1:진사골순대국밥,2:포베이,3:조이마루
# 31  남  30대      2~3회       이국식탁(양식)             1:에청타 한식뷔페,2:화로본,3:마찌돈
# 32  남  30대      0~1회       감성집밥(한식)  1:1. 한식뷔페,2:2. 진사골순대국,3:3. 놀부부대찌개
# 33  남  30대      4~5회       감성집밥(한식)           1:청계에이스타워,2:화로본갈비,3:조이마루
# 34  남  30대      4~5회       감성집밥(한식)        1:놀부부대찌개,2:진사골순대국,3:월수금김치찌개
# 35  남  20대      2~3회       감성집밥(한식)                  1:청담,2:마찌돈,3:청계국밥
# 36  남  30대      2~3회       감성집밥(한식)            1:진사골순대국밥,2:월남선생,3:조이마루
# 37  남  20대      2~3회       감성집밥(한식)              1:진사골 순대국,2:뽕차이,3:마찌돈
# 38  남  30대      4~5회       감성집밥(한식)              1:동남집,2:뽕차이,3:청진동 해장국
# 39  남  30대      0~1회       감성집밥(한식)      1:한우곰탕(계란말이맛집),2:명태골,3:청계한식뷔폐
# 40  남  20대      4~5회       감성집밥(한식)             1:함흥면옥,2:최고당돈가스,3:한식뷔페
# 41  남  20대      2~3회       감성집밥(한식)            1:서브웨이,2:샐러드박스,3:청담한식뷔페
# 42  남  30대      4~5회       감성집밥(한식)              1:월남선생,2:조이마루,3:개성칼국수
# 43  남  20대      0~1회       감성집밥(한식)            1:청담한식뷔페,2:서브웨이,3:바우네곰당
# 44  남  20대      0~1회       감성집밥(한식)             1:프랭크버거,2:롯데리아,3:스캔들버거
# 45  남  30대      2~3회       감성집밥(한식)    1:1. 청계한식뷔페,2:2. 서브웨이,3:3. 나주곰탕
# 46  남  20대      0~1회            샐러드               1:청계한식뷔페,2:참진,3:조이마루
# 47  여  20대      0~1회       감성집밥(한식)                     1:돈뚝,2:오투,3:참진
# 48  남  20대      2~3회            샐러드                1:샐러드,2:이국식탁,3:감성집밥
# 49  여  20대      2~3회      양식동원(도시락)                1:조이마루,2:쭈꾸미,3:개성샤브
# 50  남  50대      4~5회       감성집밥(한식)        1:진지방순대국,2:신청진동감자탕,3:놀부부대찌개
# 51  남  50대      4~5회            샐러드                     1:모름,2:모름,3:모름
# 52  남  50대      4~5회       이국식탁(양식)                        1:.,2:.,3:.
# 53  남  50대      2~3회       감성집밥(한식)                  1:칭메이,2:동남집,3:탁이네
# 54  남  50대      4~5회       감성집밥(한식)           1:동편옥,2:정감회식탁,3:전주명가콩나물국
# 55  남  50대      4~5회       감성집밥(한식)          1:월수금,2:은희네해장국,3:전주콩나물해장국
# 56  남  50대      4~5회       이국식탁(양식)                     1:없음,2:없음,3:없음
# 57  남  50대      4~5회            샐러드                        1:.,2:.,3:.
#
#                                               선호하는 이유
# 0                                            1:가깝다...
# 1   1:좋아하는 메뉴이기도 하고 주문 후 늦지 않게 음식이 나오며 나름의 합리적인 가격...
# 2                                        1:국물이 끝내줍니다.
# 3                                               1:맛있음
# 4                                             1:해장, 맛
# 5                                      1:회사 식당이 맛이 없다
# 6                                   1:다양한 메뉴 및 저렴한 가격
# 7   1:회사에 오면 그냥 일반 집밥보다는 뭔가 맛잇는거를 먹고 싶어서. 회사 구내식당은...
# 8   1:청계 에이스 타워 내에 있는 음식점들을 선호합니다... 가까워서요 ,,,,점심시...
# 9            1:개인적으로 매운 음식을 잘 먹지 못해서 순한 음식이 나오는 곳을 선호
# 10                                             1:맛있어서
# 11                1:1. 맛이 좋아서 2. 계란 반찬을 많이 줘서 3. 가까워서
# 12                                  1:맛있다 좋아하는메뉴 깔끔하다
# 13                                                NaN
# 14  1:가격이 비싸지만 값어치를 함. 맛있게 깨끗하고, 돈을 내고 대접을 받는기분이지만...
# 15                   1:외부 식당을 잘 이용안해서 사실 아는데가 많지 않아요.
# 16                                 1:개인적인 좋아하는 메뉴입니다.
# 17                   1:음식이 빨리 나오고 미리 오더가 가능하며 맛이 좋아요.
# 18                                      1:가까워서 선호합니다.
# 19                                         1:푸짐하고 맛있음
# 20                                                NaN
# 21                                            1:맛있어서요
# 22  1:청담 한식뷔페 : 다양한 메뉴를 자율배식으로 먹을 수 있다. 뽕차이 : 농협IT...
# 23                    1:가깝고 맛있어서, 점심시간에 함께하는 지인이 선호해서
# 24                                    1:가성비가 좋고 맛이 좋음
# 25                                             1:맛있어서
# 26                                              1:편해서
# 27                               1:2층 식당만 아니면 다좋습니다..
# 28                                    1:든든한 메뉴가 좋습니다~
# 29                                          1:가격대비 효율
# 30  1:좋아하는 음식을 판다. 음식이 맛있다. 도보권 내에 있다. 장부가 있다. 해장할...
# 31                                   1:가깝고 가성비가 좋습니다!
# 32  1:1. 매일매일 바뀌는 메뉴를 푸짐하게 먹을수있고 구내식당과 가격차이도 별로안남....
# 33                                                NaN
# 34                                       1:해장하기 좋습니다.
# 35                                    1:2층 식당의 대안으로..
# 36                                   1:점심에 간단히 먹기 좋네요
# 37  1:음식이 빨리 나오고 근처 식당중에 육계장이 가장 맛있는 집입니다. 해장하기 좋습...
# 38  1:가끔 국물 있는 걸 먹고 싶을 때가 있어 나가게 되면 주로 먹는다 2층은 뭔가 ...
# 39                    1:가격이 저렴함 맛이 훌륭함 직원분이 서비스의식이 있음
# 40              1:2층에서 먹기 싫을때 가까이 있는 식당이고 맛있음 메뉴가 다양함
# 41  1:점심을 가볍게 먹고싶을때는 서브웨이나 샐러드박스에 가고, 든든하게 먹고 싶을때는...
# 42                                                NaN
# 43                                          1:메뉴의 다양함
# 44                                      1:햄버거를 좋아합니다.
# 45                                  1:가성비가 좋은 것 같습니다.
# 46                                    1:다양한 메뉴와 깔끔한 맛
# 47                                           1:간이 적절함
# 48                                         1:가성비가 좋다.
# 49                                                NaN
# 50                                             1:맛있어서
# 51                                                NaN
# 52                                                1:.
# 53                        1:이용하기 편함 예약이 가능하여 식사 시간 단축
# 54            1:회식 후 해장 등 간단히 단품으로 먹을 수 있는 국물있는 음식입니다
# 55                                          1:맛있고 저렴함
# 56                                               1:없음
# 57                                                1:.

# %% [markdown]
# # 플랏 함수

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
flights = sns.load_dataset('flights')

# %%
## bar_plot
### excel_path : 엑셀파일 경로
### column_name : 원하는 컬럼 이름
### figsize : plot size, default = (10.8), 크기 조정 가능

def bar_plot(excel_path, column_name, figsize=(10,8)):
    df = pd.read_excel(excel_path)
    df_column = pd.DataFrame(df[column_name].value_counts())
    df_column = df_column.rename(columns={column_name:'Count'})

    plt.figure(figsize=figsize)
    plt.xlabel('Count')
    plt.title(column_name)

    sns.barplot(x=df_column['Count'],y=df_column.index)

# %%
## 예시
excel = "./Survey.xlsx"
bar_plot(excel,"구내식당 선호 메뉴", figsize=(16,4))

# %%
## pie_plot
### excel_path : 엑셀파일 경로
### column_name : 원하는 컬럼 이름
### figsize : plot size, default = (10.10), 크기 조정 가능

def pie_plot(excel_path, column_name, figsize=(10,10)):

    df = pd.read_excel(excel_path)
    df_column = pd.DataFrame(df[column_name].value_counts())
    df_column = df_column.rename(columns={column_name:'Count'})

    ratio = [i for i in df_column["Count"]]
    ratio = [i/sum(ratio) for i in ratio]
    labels = [i for i in df_column.index]
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 5} # 부채꼴 스타일 지정하기

    plt.figure(figsize=figsize)
    plt.title(column_name)
    plt.pie(ratio, labels=labels,autopct='%.1f%%', wedgeprops=wedgeprops)
    plt.show

# %%
## 예시
pie_plot(excel, "구내식당 선호 메뉴")

# %%
## 두개 컬럼을 사용하여 분석
## ex) first_column = "연령대",contents = "40대" ,sec_column = "구내식당 선호메뉴"
##     >> 연령대가 40대인 사원들의 구내식당 선호메뉴 비중

def columns_analysis(excel_path, first_column, contents, sec_column, figsize=(10,10)):
    df = pd.read_excel(excel_path)
    df = df[df[first_column]== contents]
    df = pd.DataFrame(df[sec_column].value_counts())
    df = df.rename(columns={sec_column:'Count'})

    ratio = [i for i in df["Count"]]
    ratio = [i/sum(ratio) for i in ratio]
    labels = [i for i in df.index]
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 5} # 부채꼴 스타일 지정하기

    plt.figure(figsize=figsize)
    plt.title(contents+' '+sec_column)
    plt.pie(ratio, labels=labels,autopct='%.1f%%', wedgeprops=wedgeprops)
    plt.show

# %%
columns_analysis(excel,"연령대", "40대", "구내식당 선호 메뉴")
