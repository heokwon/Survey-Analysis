# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/Survey-analysis/blob/main/Another_Survey_visualiziatoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Seaborn 한글깨짐 해결위한 install

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (47.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 159447 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # 플랏 함수

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
plt.rc('font', family='NanumBarunGothic')
flights = sns.load_dataset('flights')

# %%
## 전처리
def clean_content(content):
  cleaned = re.sub('[^가-힣ㄱ-ㅣa-zA-Z|.%]', ' ', string=str(content))
  cleaned = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', cleaned)
  return cleaned

# %%
df=pd.read_excel('/content/Calendar.xlsx')
col_lst = [i for i in df.columns[3:]]
for i in col_lst:
    df[i] = df[i].apply(clean_content)

# %%
df.to_excel('./re_Calendar.xlsx')

# %%
col_lst
# Out:
# ['귀하의 소속사무소는 다음 중 어디에 해당합니까?',
#  '금년도(2022년형) 달력류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?',
#  '금년도(2022년형) 달력류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요?',
#  '금년도(2022년형) 수첩류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?',
#  '금년도(2022년형) 수첩류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요?',
#  '금년도(2022년형) 연하장류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?',
#  '금년도(2022년형) 연하장류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요? ',
#  '금년도(2022년형) 달력·수첩류 배송에 대해 어떻게 생각하십니까?',
#  '금년도(2022년형) 달력·수첩류 배송에 대해 그렇게 생각하시는 이유는 무엇인가요? (선택)',
#  '농민신문사에서는 금년도(2022년형) 달력류를 각 개인에게 직접 발송하는 농민신문사 DM발송서비스를 (2형캘린더 일반·명칭형, 3형캘린더, 연하장)일부 시행했습니다. 이 서비스를 유지할 경우 이용할 의향이 있으십니까?',
#  '전제적인 구매 과정에서 개선이 필요하다고 생각했던 사항이 있으셨나요? 아래 보기 중 가장 개선이 시급한 사항을 골라주세요',
#  '2022년형 삼각식캘린더를 기존 단면월력에서 양면월력으로 변경하였는데 어떻게 생각하십니까?',
#  '2021년형 탁상용 삼각식캘린더 단면월력과 2022년형 탁상용 삼각식캘린더 양면월력 동시 판매에  대해 어떻게 생각하십니까? ',
#  '금년도(2022년형) 달력,수첩류 제품의 가격에 대해 어떻게 생각하십니까?',
#  '달력·수첩류에 대한 의견이 있으시면 구체적으로 적어주십시오.',
#  '구매한 제품, 서비스에 대한 전반적인 만족도를 어떻게 평가 하시겠습니까?']

# %%
df
# Out:
#         순번     직급   직명 귀하의 소속사무소는 다음 중 어디에 해당합니까?  \
# 0        1     3급   팀장               경제지주 및 경제계열사
# 1        2     4급   차장                        중앙회
# 2        3     4급   차장               경제지주 및 경제계열사
# 3        4     3급   반장                        중앙회
# 4        5     4급   차장               경제지주 및 경제계열사
# ...    ...    ...  ...                        ...
# 2337  2338  무기계약직   주임               경제지주 및 경제계열사
# 2338  2339      -  영양사                        중앙회
# 2339  2340     기타   기타               금융지주 및 금융계열사
# 2340  2341      -   주임                        중앙회
# 2341  2342     4급   차장                        중앙회
#
#      금년도(2022년형) 달력류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?  \
# 0                                                매우만족
# 1                                                 불만족
# 2                                                매우만족
# 3                                                  보통
# 4                                                  만족
# ...                                               ...
# 2337                                              불만족
# 2338                                             매우만족
# 2339                                             매우만족
# 2340                                               만족
# 2341                                               만족
#
#      금년도(2022년형) 달력류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요?  \
# 0                                      다양한 색상과 크기
# 1                                     탁상형 달력 양면인쇄
# 2                             전반적으로 디자인이 괜찮다고 생각함
# 3                                       전반적으로 쏘쏘함
# 4                                          세련된 느낌
# ...                                           ...
# 2337                절약차원에서 앞뒤로 달이 연결되어 있는 것이 불편하다
# 2338                                          무난함
# 2339                                   깔끔하고 심플합니다
# 2340                                            ㅎ
# 2341                                           깔끔
#
#      금년도(2022년형) 수첩류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?  \
# 0                                                매우만족
# 1                                                  만족
# 2                                                  만족
# 3                                                  보통
# 4                                                매우만족
# ...                                               ...
# 2337                                               만족
# 2338                                             매우만족
# 2339                                             매우만족
# 2340                                               만족
# 2341                                               만족
#
#      금년도(2022년형) 수첩류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요?  \
# 0                                      다양한 색상과 크기
# 1                                             nan
# 2            휴대용 수첩에 기존처럼 명함을 넣을 수 있도록 비닐이 있었으면 함
# 3                                       전반적으로 쏘쏘함
# 4                                        트렌디하고 이쁨
# ...                                           ...
# 2337                             디자인과 색깔이 좋은 거 같다
# 2338                디자인이 깔끔하고 내용도 좋고 자석뭍임 여닫음이 좋음
# 2339                                       디자인 만족
# 2340                                            ㅎ
# 2341                                           깨꿋
#
#      금년도(2022년형) 연하장류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?  \
# 0                                                 매우만족
# 1                                                   보통
# 2                                                 매우만족
# 3                                                   보통
# 4                                                 매우만족
# ...                                                ...
# 2337                                                보통
# 2338                                              매우만족
# 2339                                                보통
# 2340                                                만족
# 2341                                                만족
#
#      금년도(2022년형) 연하장류 디자인에 대해 그렇게 생각하시는 이유는 무엇인가요?   \
# 0                                        다양한 색상과 크기
# 1                                               nan
# 2                                           사용하지 않음
# 3                                         전반적으로 쏘쏘함
# 4                                                예쁨
# ...                                             ...
# 2337                           연하장을 본 적이 없어서 잘 모르겠다
# 2338                                            무난함
# 2339                                     거의 사용하지 않음
# 2340                                              ㅎ
# 2341                                             선명
#
#      금년도(2022년형) 달력·수첩류 배송에 대해 어떻게 생각하십니까?  \
# 0                                       만족
# 1                                       만족
# 2                                     매우만족
# 3                                       만족
# 4                                     매우만족
# ...                                    ...
# 2337                                    보통
# 2338                                    보통
# 2339                                  매우만족
# 2340                                    만족
# 2341                                    만족
#
#      금년도(2022년형) 달력·수첩류 배송에 대해 그렇게 생각하시는 이유는 무엇인가요? (선택)  \
# 0                                              타 업무에 집중
# 1                                                   nan
# 2                                      배송이 빨리 이뤄졌다고 생각함
# 3                                             전반적으로 쏘쏘함
# 4                                                    예쁨
# ...                                                 ...
# 2337                             배송을 직접 담당하지 않아서 잘 모르겠다
# 2338                                                느렸음
# 2339                                         잘 배송되어서 만족
# 2340                                                  ㅎ
# 2341                                                 빠름
#
#      농민신문사에서는 금년도(2022년형) 달력류를 각 개인에게 직접 발송하는 농민신문사 DM발송서비스를 (2형캘린더 일반·명칭형, 3형캘린더, 연하장)일부 시행했습니다. 이 서비스를 유지할 경우 이용할 의향이 있으십니까?  \
# 0                                                  이용한다
# 1                                                  이용한다
# 2                                               이용하지않는다
# 3                                                  이용한다
# 4                                                  이용한다
# ...                                                 ...
# 2337                                               모르겠다
# 2338                                               모르겠다
# 2339                                               이용한다
# 2340                                               모르겠다
# 2341                                               모르겠다
#
#      전제적인 구매 과정에서 개선이 필요하다고 생각했던 사항이 있으셨나요? 아래 보기 중 가장 개선이 시급한 사항을 골라주세요  \
# 0                                                    기타
# 1                                                   디자인
# 2                                                   디자인
# 3                                                    기타
# 4                                                    크기
# ...                                                 ...
# 2337                                                디자인
# 2338                                                 배송
# 2339                                              소재 품질
# 2340                                                 크기
# 2341                                              소재 품질
#
#      2022년형 삼각식캘린더를 기존 단면월력에서 양면월력으로 변경하였는데 어떻게 생각하십니까?  \
# 0                                                    만족
# 1                                                 매우불만족
# 2                                                  매우만족
# 3                                                   불만족
# 4                                                  매우만족
# ...                                                 ...
# 2337                                                불만족
# 2338                                                 보통
# 2339                                               매우만족
# 2340                                                 만족
# 2341                                                불만족
#
#      2021년형 탁상용 삼각식캘린더 단면월력과 2022년형 탁상용 삼각식캘린더 양면월력 동시 판매에  대해 어떻게 생각하십니까?   \
# 0                                    찬성 단면월력 양면월력 동시판매
# 1                                       반대 단면월력으로 상품교체
# 2                                    찬성 단면월력 양면월력 동시판매
# 3                                    찬성 단면월력 양면월력 동시판매
# 4                                    찬성 단면월력 양면월력 동시판매
# ...                                                 ...
# 2337                                    반대 단면월력으로 상품교체
# 2338                                 찬성 단면월력 양면월력 동시판매
# 2339                                 찬성 단면월력 양면월력 동시판매
# 2340                                    반대 단면월력으로 상품교체
# 2341                                    반대 단면월력으로 상품교체
#
#      금년도(2022년형) 달력,수첩류 제품의 가격에 대해 어떻게 생각하십니까?  \
# 0                                          비싸다
# 1                                          비싸다
# 2                                         적당하다
# 3                                         적당하다
# 4                                         적당하다
# ...                                        ...
# 2337                                       비싸다
# 2338                                      적당하다
# 2339                                      적당하다
# 2340                                      적당하다
# 2341                                      적당하다
#
#       달력·수첩류에 대한 의견이 있으시면 구체적으로 적어주십시오.  \
# 0                   올해 디자인 및 다양한 색상에 만족
# 1                                   nan
# 2     수첩 제작시 사용자들이 사용하기 편리하기 만들어 주었으면 함
# 3                               특이사항 없음
# 4                                   이뻐요
# ...                                 ...
# 2337                      달력은 단면이 실용적이다
# 2338                                 없음
# 2339                           대체적으로 만족
# 2340                                  ㅎ
# 2341                      깔끔하고 선명하게 디자인
#
#      구매한 제품, 서비스에 대한 전반적인 만족도를 어떻게 평가 하시겠습니까?
# 0                                        매우만족
# 1                                          보통
# 2                                        매우만족
# 3                                          만족
# 4                                        매우만족
# ...                                       ...
# 2337                                       보통
# 2338                                       만족
# 2339                                       만족
# 2340                                       만족
# 2341                                       만족
#
# [2342 rows x 19 columns]

# %%
## bar_plot
### excel_path : 엑셀파일 경로
### column_name : 원하는 컬럼 이름
### figsize : plot size, default = (10.8), 크기 조정 가능

def bar_plot(excel_path, column_name, figsize=(10,8)):
    df = pd.read_excel(excel_path)
    df_column = pd.DataFrame(df[column_name].value_counts())
    df_column = df_column.rename(columns={column_name:'Count'})

    plt.figure(figsize=figsize)
    plt.xlabel('Count')
    plt.title(column_name)

    sns.barplot(x=df_column['Count'],y=df_column.index)

# %%
## 예시
excel = "/content/re_Calendar.xlsx"
bar_plot(excel,"귀하의 소속사무소는 다음 중 어디에 해당합니까?", figsize=(16,4))

# %%
def hist_plot(excel_path, age_group, column_name, figsize=(10,8)):
    df = pd.read_excel(excel_path)
    plt.figure(figsize=figsize)
    plt.title(age_group+' '+column_name)

    sns.histplot(data=df, y=age_group, hue=column_name, multiple="stack")

# %%
excel = "/content/re_Calendar.xlsx"
hist_plot(excel,'직급','금년도(2022년형) 연하장류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?',(16,16))

# %%
def gender_histplot(excel_path, gender,MorF, age_group, column_name, figsize=(10,8)):
    df = pd.read_excel(excel_path)
    df = df[df[gender]==MorF]
    plt.figure(figsize=figsize)
    plt.title(gender+' '+age_group+' '+column_name)

    sns.histplot(data=df, y=age_group, hue=column_name, multiple="stack")

# %%
gender_histplot(excel,'직급','4급','직명','금년도(2022년형) 연하장류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?',(16,8))

# %%
## strip_plot(엑셀 경로, 성별or연령대, 구내식당 이용빈도or구내식당 선호 메뉴)

def strip_plot(excel,column,sec_column,figsize=(10,10)):
    df=pd.read_excel(excel)
    plt.figure(figsize=figsize)
    plt.title(column+' '+sec_column)
    sns.stripplot(x=column, y=sec_column, data=df)

# %%
strip_plot(excel,'직명','귀하의 소속사무소는 다음 중 어디에 해당합니까?', figsize=(60,10))

# %%
## pie_plot
### excel_path : 엑셀파일 경로
### column_name : 원하는 컬럼 이름
### figsize : plot size, default = (10.10), 크기 조정 가능

def pie_plot(excel_path, column_name, figsize=(10,10)):

    df = pd.read_excel(excel_path)
    df_column = pd.DataFrame(df[column_name].value_counts())
    df_column = df_column.rename(columns={column_name:'Count'})

    ratio = [i for i in df_column["Count"]]
    ratio = [i/sum(ratio) for i in ratio]
    labels = [i for i in df_column.index]
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 5} # 부채꼴 스타일 지정하기

    plt.figure(figsize=figsize)
    plt.title(column_name)
    plt.pie(ratio, labels=labels,autopct='%.1f%%', wedgeprops=wedgeprops)
    plt.show

# %%
## 예시
pie_plot(excel, '금년도(2022년형) 달력류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?')

# %%
## 두개 컬럼을 사용하여 분석
## ex) first_column = "연령대",contents = "40대" ,sec_column = "구내식당 선호메뉴"
##     >> 연령대가 40대인 사원들의 구내식당 선호메뉴 비중

def columns_analysis(excel_path, first_column, contents, sec_column, figsize=(10,10)):
    df = pd.read_excel(excel_path)
    df = df[df[first_column]== contents]
    df = pd.DataFrame(df[sec_column].value_counts())
    df = df.rename(columns={sec_column:'Count'})

    ratio = [i for i in df["Count"]]
    ratio = [i/sum(ratio) for i in ratio]
    labels = [i for i in df.index]
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 5} # 부채꼴 스타일 지정하기

    plt.figure(figsize=figsize)
    plt.title(contents+' '+sec_column)
    plt.pie(ratio, labels=labels,autopct='%.1f%%', wedgeprops=wedgeprops)
    plt.show

# %%
columns_analysis(excel,"직급", "4급", "금년도(2022년형) 달력류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?")

# %%
## 성별 + 연령대 분석
## ex) 남 40대 구내식당 선호메뉴
## gender_analysis_pieplot(엑셀경로, 성별, 남or여, 20 30 40 50대 중 택1, 구내식당 이용빈도 or 구내식당 선호 메뉴)

def gender_analysis_pieplot(excel_path, gender_column, age_columns, Gender, age_group, sec_column,figsize=(10,10)):
    df = pd.read_excel(excel_path)
    gender = df[df[gender_column]==Gender]
    gender_AgeGroup = gender[gender[age_columns]==age_group]
    gender_AgeGroup = pd.DataFrame(gender_AgeGroup[sec_column].value_counts())

    ratio = [i for i in gender_AgeGroup[sec_column]]
    ratio = [i/sum(ratio) for i in ratio]
    labels = [i for i in gender_AgeGroup.index]
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 5} 

    plt.figure(figsize=figsize)
    plt.title(Gender+' '+age_group+' '+sec_column)
    plt.pie(ratio, labels=labels,autopct='%.1f%%', wedgeprops=wedgeprops)
    plt.show

# %%
gender_analysis_pieplot(excel,'귀하의 소속사무소는 다음 중 어디에 해당합니까?','중앙회','직급','4급','금년도(2022년형) 수첩류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '중앙회'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-890c96417a16> in <module>
# ----> 1 gender_analysis_pieplot(excel,'귀하의 소속사무소는 다음 중 어디에 해당합니까?','중앙회','직급','4급','금년도(2022년형) 수첩류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?')
#
# <ipython-input-49-8c4b9c73cbf7> in gender_analysis_pieplot(excel_path, gender_column, age_columns, Gender, age_group, sec_column, figsize)
#       6     df = pd.read_excel(excel_path)
#       7     gender = df[df[gender_column]==Gender]
# ----> 8     gender_AgeGroup = gender[gender[age_columns]==age_group]
#       9     gender_AgeGroup = pd.DataFrame(gender_AgeGroup[sec_column].value_counts())
#      10
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '중앙회'

# %%
excel='/content/re_NH_Survey.xlsx'
gender_analysis_pieplot(excel,'성별','남','연령대','40대','구내식당 선호 메뉴')

# %%
#@title
# ## 성별&연령대별 구내식당 선호 메뉴 or 구내식당 이용빈도 카운트
# ## count_df(엑셀경로, 남or여, 구내식당 선호 메뉴or구내식당 이용빈도)

# def count_df(excel_path, gender, column_name):
#     df = pd.read_excel(excel_path)
#     col_list = ['20대','30대','40대','50대']
#     index_list = [i for i in df[column_name].drop_duplicates()]

#     new_df = {'20대':[],
#               '30대':[],
#               '40대':[],
#               '50대':[]}

#     for col in col_list:
#         for index in index_list:
#             new = (df['성별']==gender) & (df['연령대']==col) & (df[column_name]==index)
#             count = len(df[new])
#             new_df[col].append(count)

#     new_df = pd.DataFrame(new_df,index = index_list)
#     new_df['합계'] = new_df.sum(axis=1)
#     new_df.loc['합계'] = new_df.sum(axis=0) 

#     return new_df

# %%
#@title
# excel = '/content/re_NH_Survey.xlsx'
# count_df(excel,'남','구내식당 선호 메뉴')

# %%
def count_df2(excel_path, age_col, analysis_col, gen_col, gender):
    df = pd.read_excel(excel_path)
    col_list = [i for i in df[age_col].drop_duplicates()]
    index_list = [i for i in df[analysis_col].drop_duplicates()]
    
    new_df = {}
    for i in range(len(col_list)):
        new_df[col_list[i]] = []

    for col in col_list:
        for index in index_list:
            new = (df[gen_col]==gender) & (df[age_col]==col) & (df[analysis_col]==index)
            count = len(df[new])
            new_df[col].append(count)

    new_df = pd.DataFrame(new_df,index = index_list)
    new_df['합계'] = new_df.sum(axis=1)
    new_df.loc['합계'] = new_df.sum(axis=0)

    return new_df

# %%
count_df2(excel, '직급', '금년도(2022년형) 수첩류 디자인 및 제작사양에 대해 전반적으로 어떻게 생각하십니까?', '직명','차장')
# Out:
#            3급   4급  5급   -  생산직  별정직  계약직  보험심사직  기간제근로자  연봉제일반직  ...  5급을  \
#     매우만족    0   29   0   8    0    0    1      0       0       7  ...    0
#     만족      1   76   0   9    0    0    1      0       0      20  ...    0
#     보통      1   60   0  11    0    1    2      0       0      19  ...    0
#     불만족     0   27   0   2    0    0    0      0       0      11  ...    0
#     매우불만족   0    9   0   1    0    0    0      0       0       4  ...    0
# 합계          2  201   0  31    0    1    4      0       0      61  ...    0
#
#            차장S  사원  sw품질검증  금융정보제공  전산HelpDesk  용역직  무기계약직  기타   합계
#     매우만족     0   0       0       0           0    0      0   0   47
#     만족       0   0       0       0           0    0      0   0  117
#     보통       0   0       0       0           0    0      0   0  101
#     불만족      0   0       0       0           0    0      0   0   45
#     매우불만족    0   0       0       0           0    0      0   0   16
# 합계           0   0       0       0           0    0      0   0  326
#
# [6 rows x 48 columns]
